# %% [markdown]
# # AI - LAB

# %% [markdown]
# # TASK 9

# %% [markdown]
# Name:Fizza Farooq

# %% [markdown]
# Rollnumber: su92-bsdsm-f23-017

# %% [markdown]
# # Libraries

# %%
import pandas as pd

# %% [markdown]
# Data Loading

# %%
df = pd.read_csv("dataset.csv")
df
# Out:
#      Unnamed: 0                                        source_text  \
# 0             0  Researchers have discovered a new species of b...
# 1             1  The moon orbits the Earth in approximately 27....
# 2             2  Water is composed of two hydrogen atoms and on...
# 3             3          The history of Rome dates back to 753 BC.
# 4             4  Pluto was once considered the ninth planet in ...
# ..          ...                                                ...
# 365         397   Playing musical instruments enhances creativity.
# 366         398  Studying history helps in understanding the pr...
# 367         399    Listening to classical music can improve focus.
# 368         400     Practicing yoga enhances physical flexibility.
# 369         401             Volunteering fosters community spirit.
#
#                                       plagiarized_text  label
# 0    Scientists have found a previously unknown but...      1
# ...

# %% [markdown]
# # Data Exploration

# %%
print(f"Number of Rows: {df.shape[0]}")
print(f"Number of Columns: {df.shape[1]}")
# Out:
# Number of Rows: 370
# Number of Columns: 4

# %%
df.head(4)
# Out:
#    Unnamed: 0                                        source_text  \
# 0           0  Researchers have discovered a new species of b...
# 1           1  The moon orbits the Earth in approximately 27....
# 2           2  Water is composed of two hydrogen atoms and on...
# 3           3          The history of Rome dates back to 753 BC.
#
#                                     plagiarized_text  label
# 0  Scientists have found a previously unknown but...      1
# 1  Our natural satellite takes around 27.3 days t...      1
# 2  H2O consists of 2 hydrogen atoms and 1 oxygen ...      1
# 3  Rome has a long history that can be traced bac...      1

# %%
df.tail(4)
# Out:
#      Unnamed: 0                                        source_text  \
# 366         398  Studying history helps in understanding the pr...
# 367         399    Listening to classical music can improve focus.
# 368         400     Practicing yoga enhances physical flexibility.
# 369         401             Volunteering fosters community spirit.
#
#                                       plagiarized_text  label
# 366  Understanding the present is aided by studying...      0
# 367  Focus is improved by listening to classical mu...      0
# 368  Physical flexibility is enhanced by practicing...      0
# 369      Community spirit is fostered by volunteering.      0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# source_text         0
# plagiarized_text    0
# label               0
# dtype: int64

# %%
df.count()
# Out:
# Unnamed: 0          370
# source_text         370
# plagiarized_text    370
# label               370
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0       label
# count  370.000000  370.000000
# mean   206.591892    0.494595
# std    117.774570    0.500648
# min      0.000000    0.000000
# 25%    112.500000    0.000000
# 50%    211.500000    0.000000
# 75%    308.750000    1.000000
# max    401.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        370 non-null    int64
#  1   source_text       370 non-null    object
#  2   plagiarized_text  370 non-null    object
#  3   label             370 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 11.7+ KB

# %%
for i in df.columns:
    print(i)
# Out:
# Unnamed: 0
# source_text
# plagiarized_text
# label

# %%
df['plagiarized_text'].unique()
# Out:
# array(['Scientists have found a previously unknown butterfly species in the Amazon jungle.',
#        'Our natural satellite takes around 27.3 days to complete one orbit around our planet.',
#        'H2O consists of 2 hydrogen atoms and 1 oxygen atom.',
#        'Rome has a long history that can be traced back to 753 BC.',
#        "In the past, Pluto was classified as the ninth planet in our sun's planetary system.",
#        'This sentence is unique and original.',
#        'AI is changing the landscape of various sectors.',
#        'Data science often relies on Python as a widely used programming language.',
#        'Our planet follows an almost circular path as it moves around the central star.',
#        "France's capital city is Paris.",
#        'Photosynthesis in plants transforms sunlight into usable energy.',
#        'Among the Seven Wonders, the Great Wall of China stands out.',
#        'The force pulling two masses together is known as gravity.',
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0          370
# source_text         365
# plagiarized_text    367
# label                 2
# dtype: int64
